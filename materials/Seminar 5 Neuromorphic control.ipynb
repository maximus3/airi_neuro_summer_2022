# %% [markdown]
# # Seminar 5. Neuromorphic control
# ## In class:
# * OpenAI Gym. Classic control environments.
# * Observations, action, reward
# * Neuro controller
# * Mutual inhibition for control
# * Parametric tuning
#
# ## Homework:
# * Explore the controller performance for "asymmetric" network where one of the neurons doesn't have sensor input and receives only synaptic connections from the other neuron.
# * Create neurocontroller for continuous mountain car environment (https://gym.openai.com/envs/MountainCarContinuous-v0/). The continuous actions may be represented by firing rates (rate coding) or by neuron numbers (spatial coding).
# * Optimize the controller parameters from scratch. You may use optimize.differential_evolution algorithm
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.differential_evolution.html#scipy.optimize.differential_evolution
# * Optimize parameters using HyperOpt https://hyperopt.github.io/hyperopt/

# %% [markdown]
# ### 1. OpenAI Gym
# Here we explore the most basic environment, CartPole (https://gym.openai.com/envs/CartPole-v1/).
#
# Observation:
#         Type: Box(4)
#
#         Num	 Observation              Min             Max
#
#         0	Cart Position             -4.8            4.8
#         1	Cart Velocity             -Inf            Inf
#         2	Pole Angle                 -24 deg        24 deg
#         3	Pole Velocity At Tip      -Inf            Inf
#
# Actions:
#         Type: Discrete(2)
#
#         Num	Action
#         0	Push cart to the left
#         1	Push cart to the right
#
# Reward:
#
#         Reward is 1 for every step taken, including the termination step

# %%
import gym
import matplotlib.pyplot as plt
# %matplotlib inline

class RandomController:
    def __init__(self):
        self.action_space = gym.spaces.Discrete(2)
        
    def next_action(self, observation):
        # print(observation)
        return self.action_space.sample()
    
def control_cartpole(controller, show=True, print_log=True):
    env = gym.make("CartPole-v1") 
    obs = env.reset()
    R = 0
    if print_log:
        print("Step \t CartPosition CartVelocity PoleAngle PoleVelocity \t Action")
    for i in range(200):
        # plt.imshow(env.render(mode='rgb_array'))
        # display.display(plt.gcf())    
        # display.clear_output(wait=True)
        action = controller.next_action(obs)
        if print_log:
            print(f"{i}\t{obs[0]:12.4f}{obs[1]:12.4f}{obs[2]:12.4f}{obs[3]:12.4f}\t{action}")
        obs, reward, done, _ = env.step(action)
        R += reward
        if show:
            env.render()
        if done:
            break
    env.close()
    if print_log:
        print(f"Finished in {i+1} steps")
        print(f"Total reward = {R}")      
    return R

# %%
control_cartpole(RandomController())
# Out:
# Step 	 CartPosition CartVelocity PoleAngle PoleVelocity 	 Action
# 0	      0.0096     -0.0200      0.0197     -0.0156	1
# 1	      0.0092      0.1748      0.0194     -0.3020	1
# 2	      0.0127      0.3696      0.0133     -0.5885	1
# 3	      0.0201      0.5646      0.0016     -0.8770	1
# 4	      0.0314      0.7597     -0.0160     -1.1691	1
# 5	      0.0466      0.9550     -0.0393     -1.4668	1
# 6	      0.0657      1.1506     -0.0687     -1.7715	1
# 7	      0.0887      1.3464     -0.1041     -2.0847	1
# 8	      0.1156      1.5424     -0.1458     -2.4077	0
# 9	      0.1465      1.3488     -0.1940     -2.1631	0
# Finished in 10 steps
# Total reward = 10.0
# 10.0

# %% [markdown]
# ### 2. Neuro controller
# Here we create two LIF "motor neurons" for "Left" and "Right" actions.
# The synaptic inputs come from the observations.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import brian2 as b2
import numpy as np
import random

class NeuroController:
    LEFT = 0
    RIGHT = 1
        
    def __init__(self, tau, w_sensor, I_tonic):
        # b2.start_scope() # clear the Brian scope
        eqs = '''
            dv/dt = (inp-v+I_t)/tau: 1
            inp : 1
            tau : second
            I_t : 1
            '''
        G = b2.NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='linear')
        self.neurons = G
        self.neurons.tau = tau
        self.neurons.v = [0,0]
        self.neurons.I_t = I_tonic
        self.w_sensor = w_sensor
        self.T_step = 1/50 * b2.second
        self.spike_mon = b2.SpikeMonitor(G)
        self.v_mon = b2.StateMonitor(G, "v", record=True)
        self.net = b2.Network(self.neurons, self.spike_mon, self.v_mon)
    
    def next_action(self, observation):
        self.neurons.inp = observation@self.w_sensor
        prev_spikes = np.array(self.spike_mon.count)
        self.net.run(self.T_step)
        new_spikes = self.spike_mon.count - prev_spikes
        left = new_spikes[NeuroController.LEFT]
        right = new_spikes[NeuroController.RIGHT]
        if right > left:
            return NeuroController.RIGHT
        elif right < left:
            return NeuroController.LEFT
        else:
            return random.randrange(2)

# %% [markdown]
# ### 3. Input weights and tonic drive
#
# * explore how sensor weights influence control
# * add tonic drive current I_ton to both neurons
#
# #### Hint:
# The important parameters are CartVelocity and PoleAngle

# %%
def plot_v_spikes(v_mon, s_mon, t_bounds=None):
    b2.figure(figsize=(12,4))
    b2.subplot(121)
    b2.plot(v_mon.t/b2.ms, v_mon.v[0], label='left')
    b2.plot(v_mon.t/b2.ms, v_mon.v[1], label='right')
    if t_bounds:
        b2.xlim(t_bounds)
    b2.xlabel('Time (ms)')
    b2.ylabel('v')
    b2.legend();
    b2.subplot(122)
    b2.plot(s_mon.t/b2.ms,s_mon.i, '.k')
    if t_bounds:
        b2.xlim(t_bounds)
    b2.xlabel('Time (ms)')
    b2.ylabel('Neuron num')

# %%
from numpy.random import default_rng
rng = default_rng()
b2.start_scope()
tau = [5*b2.ms, 5*b2.ms]

# Vary the weight from -1(1) to -100 (100)
#observation = [CartPosition, CartVelocity, PoleAngle, PoleVelocity]
#action
w_sensor = np.array([[0, 10, -50, 0],
                     [0, -10,  50, 0]]).T
I_tonic = 1
controller = NeuroController(tau, w_sensor, I_tonic)

# Add tonic current I_t to neurons in NeuroController like that:
# I_tonic = 1
# controller = NeuroController(tau, w_sensor, I_tonic)

control_cartpole(controller)
plot_v_spikes(controller.v_mon, controller.spike_mon)
# Out:
# Step 	 CartPosition CartVelocity PoleAngle PoleVelocity 	 Action
# 0	     -0.0310     -0.0396     -0.0279     -0.0057	0
# 1	     -0.0318     -0.2343     -0.0280      0.2780	1
# 2	     -0.0365     -0.0388     -0.0225     -0.0234	0
# 3	     -0.0372     -0.2336     -0.0229      0.2621	1
# 4	     -0.0419     -0.0381     -0.0177     -0.0377	0
# 5	     -0.0427     -0.2330     -0.0185      0.2493	1
# 6	     -0.0473     -0.0376     -0.0135     -0.0491	0
# 7	     -0.0481     -0.2325     -0.0144      0.2393	1
# 8	     -0.0527     -0.0372     -0.0097     -0.0579	0
# 9	     -0.0535     -0.2322     -0.0108      0.2317	1
# Finished in 110 steps
# Total reward = 110.0

# %% [markdown]
# ### Control by a half-center oscillator
# * Add inhibitory synapses to the controller network
# * Explore how mutual inhibition influence control
# * Cut sensor inputs to one of the neurons

# %%
class HCOController(NeuroController):
        
    def __init__(self, tau, w_sensor, w_syn, I_tonic):
        NeuroController.__init__(self, tau, w_sensor, I_tonic)
        self.neurons.add_attribute("w_syn")
        self.neurons.w_syn = w_syn
        S = b2.Synapses(self.neurons, self.neurons, on_pre='v_post += w_syn')
        S.connect(i=0, j=1)
        S.connect(j=0, i=1)
        self.net.add(S)

# %%
rng = default_rng()
b2.start_scope()
tau = [5*b2.ms, 5*b2.ms]

w_sensor = np.array([[0, 10, -50, 0],
                     [0, -10,  50, 0]]).T
w_syn = -1
I_tonic = 2
controller = HCOController(tau, w_sensor, w_syn, I_tonic)

control_cartpole(controller)
plot_v_spikes(controller.v_mon, controller.spike_mon, t_bounds=(0, 100))
# Out:
# Step 	 CartPosition CartVelocity PoleAngle PoleVelocity 	 Action
# 0	     -0.0446     -0.0493      0.0016      0.0349	1
# 1	     -0.0456      0.1458      0.0023     -0.2573	0
# 2	     -0.0427     -0.0493     -0.0029      0.0361	1
# 3	     -0.0437      0.1458     -0.0021     -0.2575	0
# 4	     -0.0407     -0.0493     -0.0073      0.0345	1
# 5	     -0.0417      0.1460     -0.0066     -0.2604	0
# 6	     -0.0388     -0.0491     -0.0118      0.0302	0
# 7	     -0.0398     -0.2440     -0.0112      0.3191	1
# 8	     -0.0447     -0.0487     -0.0048      0.0229	1
# 9	     -0.0456      0.1465     -0.0044     -0.2713	0
# 10	     -0.0427     -0.0486     -0.0098      0.0200	1
# 11	     -0.0437      0.1467     -0.0094     -0.2757	0
# 12	     -0.0408     -0.0483     -0.0149      0.0140	0
# 13	     -0.0417     -0.2432     -0.0146      0.3019	1
# 14	     -0.0466     -0.0479     -0.0086      0.0047	1
# 15	     -0.0475      0.1473     -0.0085     -0.2907	0
# 16	     -0.0446     -0.0477     -0.0143     -0.0007	0
# 17	     -0.0456     -0.2426     -0.0143      0.2874	1
# 18	     -0.0504     -0.0472     -0.0086     -0.0097	1
# 19	     -0.0513      0.1480     -0.0088     -0.3051	0
# 20	     -0.0484     -0.0470     -0.0149     -0.0152	0
# 21	     -0.0493     -0.2419     -0.0152      0.2728	1
# 22	     -0.0542     -0.0466     -0.0097     -0.0246	0
# 23	     -0.0551     -0.2415     -0.0102      0.2650	1
# 24	     -0.0599     -0.0463     -0.0049     -0.0309	1
# 25	     -0.0609      0.1489     -0.0055     -0.3251	0
# 26	     -0.0579     -0.0461     -0.0120     -0.0342	0
# 27	     -0.0588     -0.2411     -0.0127      0.2547	1
# 28	     -0.0636     -0.0458     -0.0076     -0.0420	1
# 29	     -0.0645      0.1494     -0.0084     -0.3371	0
# 30	     -0.0615     -0.0456     -0.0152     -0.0471	0
# 31	     -0.0625     -0.2405     -0.0161      0.2408	1
# 32	     -0.0673     -0.0451     -0.0113     -0.0569	0
# 33	     -0.0682     -0.2401     -0.0125      0.2322	1
# 84	     -0.2167     -0.4165     -0.0554      0.1119	1
# 85	     -0.2250     -0.2206     -0.0532     -0.1977	0
# 86	     -0.2294     -0.4149     -0.0571      0.0777	1
# 87	     -0.2377     -0.2190     -0.0556     -0.2324	0
# 88	     -0.2421     -0.4133     -0.0602      0.0422	1
# 89	     -0.2504     -0.2174     -0.0594     -0.2689	0
# 90	     -0.2547     -0.4116     -0.0648      0.0045	1
# 91	     -0.2630     -0.2156     -0.0647     -0.3079	0
# 92	     -0.2673     -0.4098     -0.0708     -0.0363	1
# 93	     -0.2755     -0.2137     -0.0716     -0.3505	0
# 94	     -0.2797     -0.4077     -0.0786     -0.0812	1
# 95	     -0.2879     -0.2116     -0.0802     -0.3976	0
# 96	     -0.2921     -0.4055     -0.0882     -0.1312	0
# 97	     -0.3002     -0.5992     -0.0908      0.1324	1
# 98	     -0.3122     -0.4029     -0.0881     -0.1875	0
# 99	     -0.3203     -0.5967     -0.0919      0.0761	1
# 100	     -0.3322     -0.4004     -0.0904     -0.2441	0
# 101	     -0.3402     -0.5941     -0.0952      0.0188	1
# 102	     -0.3521     -0.3977     -0.0949     -0.3023	0
# 103	     -0.3601     -0.5914     -0.1009     -0.0410	1
# 104	     -0.3719     -0.3950     -0.1017     -0.3637	0
# 105	     -0.3798     -0.5885     -0.1090     -0.1048	1
# 106	     -0.3916     -0.3920     -0.1111     -0.4298	0
# 107	     -0.3994     -0.5854     -0.1197     -0.1741	0
# 108	     -0.4111     -0.7786     -0.1232      0.0786	1
# 109	     -0.4267     -0.5820     -0.1216     -0.2503	0
# 110	     -0.4383     -0.7752     -0.1266      0.0017	1
# 111	     -0.4538     -0.5785     -0.1266     -0.3281	0
# 112	     -0.4654     -0.7716     -0.1331     -0.0779	1
# 113	     -0.4808     -0.5748     -0.1347     -0.4094	0
# 114	     -0.4923     -0.7678     -0.1429     -0.1620	1
# 115	     -0.5077     -0.5710     -0.1461     -0.4962	0
# 116	     -0.5191     -0.7638     -0.1560     -0.2529	0
# 117	     -0.5344     -0.9564     -0.1611     -0.0132	1
# 118	     -0.5535     -0.7593     -0.1614     -0.3521	0
# 119	     -0.5687     -0.9518     -0.1684     -0.1143	1
# 120	     -0.5877     -0.7548     -0.1707     -0.4550	0
# 121	     -0.6028     -0.9471     -0.1798     -0.2206	1
# 122	     -0.6218     -0.7499     -0.1842     -0.5642	0
# 123	     -0.6368     -0.9421     -0.1955     -0.3347	0
# 124	     -0.6556     -1.1339     -0.2022     -0.1095	1
# 125	     -0.6783     -0.9366     -0.2044     -0.4585	0
# Finished in 126 steps
# Total reward = 126.0

# %% [markdown]
# ### Parametric tuning
# Here we will find optimal parameters for the controller by the optimization algorithm

# %%
def create_controller(x):
    b2.start_scope()
    tau = [5*b2.ms, 5*b2.ms]
    I_tonic = x[0]
    w_syn = x[1]
    w_sensor = np.array([[0, 10, -50, 0],
                     [0, -10,  50, 0]]).T
    return HCOController(tau, w_sensor, w_syn, I_tonic)
    

def obj_fun(x, num_run = 1):
    total_R = 0
    for _ in range(num_run):
        total_R += control_cartpole(create_controller(x), 
                                    show=False, print_log=False)
    return total_R/num_run

# %%
from scipy import optimize as opt

I_t = [0,1,2]
w_syn = [-1, -0.5, -0.25, 0]
#F = []
#for i_t in I_t:
#    for w_s in w_syn: 
#        F += [(i_t, w_s, obj_fun([i_t, w_s], num_run=3))]
#print(F)
#best = max(F, key=lambda x: x[2])
#print(f"Best solution: I_tonic={best[0]}, w_syn={best[1]}. Reward={best[2]}")
bounds = [(0,3),(-1,0)]
res = opt.differential_evolution(obj_fun, bounds)
print(f"Best solution: I_tonic={res.x[0]}, w_syn={res.x[1]}. Reward={res.fun[end]}")
res_hco = create_controller(res.x)
control_cartpole(res_hco, show=True, print_log=False)
plot_v_spikes(controller.v_mon, controller.spike_mon)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-b4da4bef65e0> in <module>()
#      11 #print(f"Best solution: I_tonic={best[0]}, w_syn={best[1]}. Reward={best[2]}")
#      12 bounds = [(0,3),(-1,0)]
# ---> 13 res = opt.differential_evolution(obj_fun, bounds)
#      14 print(f"Best solution: I_tonic={res.x[0]}, w_syn={res.x[1]}. Reward={res.fun[end]}")
#      15 res_hco = create_controller(res.x)
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\scipy\optimize\_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints)
#     306                                      workers=workers,
#     307                                      constraints=constraints) as solver:
# --> 308         ret = solver.solve()
#     309
#     310     return ret
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\scipy\optimize\_differentialevolution.py in solve(self)
#     757             # evolve the population by a generation
#     758             try:
# --> 759                 next(self)
#     760             except StopIteration:
#     761                 warning_flag = True
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\scipy\optimize\_differentialevolution.py in __next__(self)
#    1073                     feasible = True
#    1074                     cv = np.atleast_2d([0.])
# -> 1075                     energy = self.func(parameters)
#    1076                     self._nfev += 1
#    1077
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\scipy\optimize\_differentialevolution.py in __call__(self, x)
#    1259
#    1260     def __call__(self, x):
# -> 1261         return self.f(x, *self.args)
#    1262
#    1263
#
# <ipython-input-40-63efa7ccf5dc> in obj_fun(x, num_run)
#      13     for _ in range(num_run):
#      14         total_R += control_cartpole(create_controller(x),
# ---> 15                                     show=False, print_log=False)
#      16     return total_R/num_run
#
# <ipython-input-28-a267657be80d> in control_cartpole(controller, show, print_log)
#      21         # display.display(plt.gcf())
#      22         # display.clear_output(wait=True)
# ---> 23         action = controller.next_action(obs)
#      24         if print_log:
#      25             print(f"{i}\t{obs[0]:12.4f}{obs[1]:12.4f}{obs[2]:12.4f}{obs[3]:12.4f}\t{action}")
#
# <ipython-input-30-2af4df8db4e7> in next_action(self, observation)
#      34         #print(self.state_mon.v)
#      35         #print(self.spike_mon.t)
# ---> 36         self.net.run(self.T_step)
#      37         new_spikes = self.spike_mon.count - prev_spikes
#      38         left = new_spikes[NeuroController.LEFT]
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\core\base.py in device_override_decorated_function(*args, **kwds)
#     278                 return getattr(curdev, name)(*args, **kwds)
#     279             else:
# --> 280                 return func(*args, **kwds)
#     281
#     282         device_override_decorated_function.__doc__ = func.__doc__
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\units\fundamentalunits.py in new_f(*args, **kwds)
#    2390                                                      get_dimensions(newkeyset[k]))
#    2391
# -> 2392             result = f(*args, **kwds)
#    2393             if 'result' in au:
#    2394                 if au['result'] == bool:
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\core\network.py in run(self, duration, report, report_period, namespace, profile, level)
#    1010             namespace = get_local_namespace(level=level+3)
#    1011
# -> 1012         self.before_run(namespace)
#    1013
#    1014         if len(all_objects) == 0:
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\core\base.py in device_override_decorated_function(*args, **kwds)
#     278                 return getattr(curdev, name)(*args, **kwds)
#     279             else:
# --> 280                 return func(*args, **kwds)
#     281
#     282         device_override_decorated_function.__doc__ = func.__doc__
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\core\network.py in before_run(self, run_namespace)
#     899             if obj.active:
#     900                 try:
# --> 901                     obj.before_run(run_namespace)
#     902                 except Exception as ex:
#     903                     raise brian_object_exception("An error occurred when preparing an object.", obj, ex)
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\groups\group.py in before_run(self, run_namespace)
#    1131                                                  template_kwds=self.template_kwds,
#    1132                                                  override_conditional_write=self.override_conditional_write,
# -> 1133                                                  codeobj_class=self.codeobj_class
#    1134                                                  )
#    1135             self.code_objects[:] = [weakref.proxy(self.codeobj)]
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\codegen\codeobject.py in create_runner_codeobj(group, code, template_name, run_namespace, user_code, variable_indices, name, check_units, needed_variables, additional_variables, template_kwds, override_conditional_write, codeobj_class)
#     414                               codeobj_class=codeobj_class,
#     415                               override_conditional_write=override_conditional_write,
# --> 416                               compiler_kwds=compiler_kwds
#     417                               )
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\devices\device.py in code_object(self, owner, name, abstract_code, variables, template_name, variable_indices, codeobj_class, template_kwds, override_conditional_write, compiler_kwds)
#     313
#     314         template_kwds.update(kwds)
# --> 315         logger.diagnostic('%s snippet (scalar):\n%s' % (name, indent(code_representation(scalar_code))))
#     316         logger.diagnostic('%s snippet (vector):\n%s' % (name, indent(code_representation(vector_code))))
#     317
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\utils\logger.py in diagnostic(self, msg, name_suffix, once)
#     332             if sent another time.
#     333         '''
# --> 334         self._log('DIAGNOSTIC', msg, name_suffix, once)
#     335
#     336     def debug(self, msg, name_suffix=None, once=False):
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\site-packages\brian2\utils\logger.py in _log(self, log_level, msg, name_suffix, once)
#     316
#     317         the_logger = logging.getLogger(name)
# --> 318         the_logger.log(LOG_LEVELS[log_level], msg)
#     319
#     320     def diagnostic(self, msg, name_suffix=None, once=False):
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in log(self, level, msg, *args, **kwargs)
#    1372                 return
#    1373         if self.isEnabledFor(level):
# -> 1374             self._log(level, msg, args, **kwargs)
#    1375
#    1376     def findCaller(self, stack_info=False):
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in _log(self, level, msg, args, exc_info, extra, stack_info)
#    1442         record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1443                                  exc_info, func, extra, sinfo)
# -> 1444         self.handle(record)
#    1445
#    1446     def handle(self, record):
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in handle(self, record)
#    1452         """
#    1453         if (not self.disabled) and self.filter(record):
# -> 1454             self.callHandlers(record)
#    1455
#    1456     def addHandler(self, hdlr):
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in callHandlers(self, record)
#    1514                 found = found + 1
#    1515                 if record.levelno >= hdlr.level:
# -> 1516                     hdlr.handle(record)
#    1517             if not c.propagate:
#    1518                 c = None    #break out
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in handle(self, record)
#     863             self.acquire()
#     864             try:
# --> 865                 self.emit(record)
#     866             finally:
#     867                 self.release()
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in emit(self, record)
#    1070         if self.stream is None:
#    1071             self.stream = self._open()
# -> 1072         StreamHandler.emit(self, record)
#    1073
#    1074     def __repr__(self):
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in emit(self, record)
#     996             stream.write(msg)
#     997             stream.write(self.terminator)
# --> 998             self.flush()
#     999         except Exception:
#    1000             self.handleError(record)
#
# C:\Users\nbazs\Anaconda3\envs\sirius\lib\logging\__init__.py in flush(self)
#     976         try:
#     977             if self.stream and hasattr(self.stream, "flush"):
# --> 978                 self.stream.flush()
#     979         finally:
#     980             self.release()
#
# KeyboardInterrupt:
